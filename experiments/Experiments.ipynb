# %%
# %matplotlib inline
# %run "../src/Run.py"
# Out:
# 2018-06-30 12:11:24,209 DEBUG backend module://ipykernel.pylab.backend_inline version unknown
# Loading data from ../data/mnist_seven.csv...
# Data loaded.

# %% [markdown]
# ## Experiments:

# %%
run_experiment(data, 0.001, 50)
# Out:
# parameters: {
# learning rate: 0.001
# num. epochs: 50
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 89.50%
# error graphs:
# 2018-06-30 01:13:03,943 DEBUG findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans (u'/home/marius/.local/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000

# %%
run_experiment(data, 0.01, 50)
# Out:
# parameters: {
# learning rate: 0.01
# num. epochs: 50
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 92.30%
# error graphs:
# 2018-06-30 10:15:44,995 DEBUG findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans (u'/home/marius/.local/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000

# %%
run_experiment(data, 0.03, 50)
# Out:
# parameters: {
# learning rate: 0.03
# num. epochs: 50
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 92.30%
# error graphs:

# %%
run_experiment(data, 0.05, 50)
# Out:
# parameters: {
# learning rate: 0.05
# num. epochs: 50
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 92.80%
# error graphs:

# %%
run_experiment(data, 0.08, 50)
# Out:
# parameters: {
# learning rate: 0.08
# num. epochs: 50
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 93.10%
# error graphs:

# %%
run_experiment(data, 0.12, 50)
# Out:
# parameters: {
# learning rate: 0.12
# num. epochs: 50
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 93.30%
# error graphs:

# %%
run_experiment(data, 0.15, 25)
# Out:
# parameters: {
# learning rate: 0.15
# num. epochs: 25
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 93.80%
# error graphs:

# %%
run_experiment(data, 0.18, 25)
# Out:
# parameters: {
# learning rate: 0.18
# num. epochs: 25
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 94.00%
# error graphs:

# %%
run_experiment(data, 0.2, 25)
# Out:
# parameters: {
# learning rate: 0.2
# num. epochs: 25
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 94.10%
# error graphs:

# %%
run_experiment(data, 0.25, 25)
# Out:
# parameters: {
# learning rate: 0.25
# num. epochs: 25
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 94.50%
# error graphs:

# %%
run_experiment(data, 0.3, 25)
# Out:
# parameters: {
# learning rate: 0.3
# num. epochs: 25
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 87.70%
# error graphs:

# %%
run_experiment(data, 0.3, 50)
# Out:
# parameters: {
# learning rate: 0.3
# num. epochs: 50
# layers:
# MultiLayerPerceptron(
# LogisticLayer(nIn: 784, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 128, activation: sigmoid),
# LogisticLayer(nIn: 128, nOut: 10, activation: softmax),
# loss: bce)
# }
# results on test set:
# Accuracy of the recognizer: 87.00%
# error graphs:
